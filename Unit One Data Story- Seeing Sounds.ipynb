# %%
import numpy as np 
import pandas as pd


import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        # %matplotlib inline 

import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# /var/folders/j6/_5nzrlts32l_krf01lvmcwk40000gn/T/ipykernel_97341/252464946.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: /Users/anjaliravi/Downloads

# %%
import pandas as pd

# %%
df = pd.read_csv('mxmh_survey_results.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#displaying the first few rows!
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
# summarizing my data!
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
# pulling up the descriptive statistics just to see!
df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     736.000000  6.290000e+02  736.000000  736.000000
# mean    25.206803       3.572758  1.589948e+06    5.837636    4.796196
# std     12.054970       3.028199  3.987261e+07    2.793054    3.028870
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  736.000000  736.000000
# mean     3.738451    2.637228
# std      3.088689    2.842017
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    5.000000
# max     10.000000   10.000000

# %%
# getting unique values in frame just to test my capabilities!
df["Hours per day"].unique()
# Out:
# array([ 3.  ,  1.5 ,  4.  ,  2.5 ,  5.  ,  1.  ,  6.  ,  8.  ,  2.  ,
#        12.  , 24.  ,  0.5 ,  0.25,  0.  ,  7.  , 10.  ,  9.  ,  0.7 ,
#         4.5 , 20.  , 16.  , 15.  , 14.  , 13.  ,  0.1 , 11.  , 18.  ])

# %%
# getting unique values in frame just to test my capabilities!
df['Hours per day'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      3.0
# 1      1.5
# 2      4.0
# 3      2.5
# 4      4.0
#       ...
# 731    2.0
# 732    1.0
# 733    6.0
# 734    5.0
# 735    2.0
# Name: Hours per day, Length: 736, dtype: float64>

# %%
# seeing if the missing values will interrupt my dataset!
df.isnull().sum()
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# ...

# %% [markdown]
# # ***Seeing Sounds: A Visual Exploration of the Intersection between Music and Emotions***

# %% [markdown]
# ## ***Allegro Rondo: The Intro***
#
# ### As best stated by Henry Longfellow, *"Music is the Universal Language of Mankind."* Throughout history, music has been a constant that has evoked emotional responses of all kinds. Whether it's the means we hear the melodies through, the specific instrumentation and composition of it all, or the genres that vary in rhythm, in tempo or in tone, music will open people up to a whole world of new experiences. As technology advanced throughout time, the luxury that was music became less of a rarity and more of an everyday staple. With the development of phonographs, later called gramophones or record players, we saw music become a household staple. Then came the MP3 player, followed by iPods, and then, the simplicity of an app on your cellular device of choice. Music quickly evolved into something of a hobby, of a step in one's daily routine, whether it was playing music or having it serenade your ears through a pair of headphones or earbuds. And as something becomes so prevalent, it inevitably bleeds into the emotional and mental aspects of the human psyche-- which ultimately begs the question: how *does* music intersect with one's mental well-being?

# %% [markdown]
# ## ***Finding My Muse: The Dataset Discovery Journey***

# %% [markdown]
# ### The Dataset Discovery process was not one of ease. As this project came to fruition, hours were spent on various websites and platforms as I searched through an innumerable amount of repositories in order to find one that satisfied my needs. Deciding on a set that met my requirements objectively was not the goal. Although there were many solid ones that I'm sure others would have deemed appropriate for the project in question, I knew I needed to find one that satisfied both the rubric-based requirements and my *own* personal standards as far as being passionate in the material. So I found myself unenthused when I stumbled upon a dataset with more than enough nuances and analytics to create a good data story, only to read the topic and find it less than riveting, sometimes unfamiliar. And then there was the other end of the spectrum, a topic that excited me to no end-- only to possess a dataset with no depth or insight. But a middle ground was finally found as I came across a dataset based on Music's Impact on Mental Health, a topic I'm passionate about with a dataset that is well-organized for the sake of coding visualizations, vast in it's research allowing for accurate and influential information due to all its categorical and quantitative variables, and intriguing in the idea that it will allow for a riveting story to be told.

# %% [markdown]
# ## ***Conductor Block: Evolution of my Musical Inquiry***
#
# ### As I began exploring my selected dataset, I kept my focus broad. All I thought was *does music connect to one's mentality?* But as I delved deeper and deeper into the variables, variables that spanned far wider than I had anticipated, my research question was reworked countless times. The dataset asked questions that were simple, general: *What's your age? Do you consent to this study? What streaming platform do you use?* But then it got more interesting, with questions delving into the genuine impact of music on their soul- *Do you play an instrument? Do you write your own music?* Then it began to get into the details of what constituted the identity of the listeners represented- *What genres do you listen to? How many hours per day do you listen? Do you listen to music in foreign languages?* Then we began to attack the mental health aspect of the study in a more specific way than I had anticipated, with direct references to diagnoses such as anxiety, depression, OCD, and insomnia. With this extensive of research, I was quickly prompted to ask multiple questions, as music's impact spans a greater distance as the variables to consider increase. We then got a bit analytical, with factors like average BPM of recorded music being considered. My singular, general, vague research question spiraled into various harmonies and melodies that incorporated notes I hadn't even thought to include initially.

# %% [markdown]
# ## ***Synesthesia: The Benefits of Musical Visualizations***
#
# ### The ability to visualize the data present in my dataset is a feat that is far more than a technological benefit. As one can see, the data provided in the survey is extensive, with each detail and category contributing in a variety of ways. The ability to visualize this tells a story in a way that emphasizes clarity and comprehensibility in a way that is far more difficult to achieve with just the table filled with data and numerics. My visuals allow for my story to be told to a larger audience that can absorb the information that answers my research question through more intelligible methods. IN addition, the handful of variables can make it hard to read tables in a way that connects each aspect to your desired results. With the use of graphs and visuals, we can better understand how each variable connects to another, and ultimately how they all relate to how music impacts mental health. It's a level of simplicity and ease that cannot be achieved by auditory or kinesthetic mediums. To see the data in an engaging manner- with labels, colors, shapes and legends- the human brain can pick up on patterns and nuances that are far more difficult to notice in rivaling formats. The conversion of raw data into appealing, harmonious graphics is a necessary medium to make my research as interesting as can be for my viewers.

# %% [markdown]
# ## ***Stage Fright: Potential Pitfalls of Musical Visualizations***
#
# ### Although absorbable and visually appealing, one must consider the potential harm that comes with data visualization. For one, it could be argued that by converting the data into graphs, it can invalidate necessary context. Visual mediums are helpful and engaging, but it can be hard to include all the nuances that tables and datasets manage to include. For issues like causation and correlation, graphs can often misrepresent the real cause of certain connections if not clarified. One could also fall too deep into the design part of making visualizations that they lose focus on the priority: making sure data is visualized in a way all can absorb. They may make things harder to understand without realizing, too focused on enjoying the way it looks to theme despite it's inaccessibility to others. These possible pitfalls certainly came into consideration as I worked with my visuals and I did my best to focus on what needed to be focused on throughout the process.

# %% [markdown]
# ## ***Tuning My Instrument: How I Transformed the Data***
#
# ### I had to run through the data visually prior to any creating just to make sure there were no missing values or inconsistencies that would allow for inaccurate rendering. In order to make my data more digestible in my graphics, I also had to make sure I grouped certain variables together correctly, such as quantitative variables and categorical ones. I also had to look at certain datasets and make sure that they were represented by the proper visualizations: scatterplots, histograms, etc. The formatting for that was certainly taken into consideration during the process.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
custom_palette = ["#FFB6C3"] #pink!
sns.set_palette(custom_palette)

plt.figure(figsize=(12, 6))  

sns.histplot(df['Age'], bins=20, color='#FFB6C3', edgecolor='black', alpha=1)
sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color":"black"})

plt.xlabel('Age', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Distribution of Age', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.grid(axis='x', linestyle='-', alpha=0.4)
plt.grid(axis='y', linestyle='-', alpha=0.4)

plt.gca().set_facecolor('#333332')
plt.show()

# %% [markdown]
# ### ***Track One: The Symphony of Age Distribution***
# ### Each piece of data corresponds to the age of a participant, each one highlighting the life experience that comes with mental health's correlation to musical engagement, with a crescendo around the ages of 15-25.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
custom_palette = ["#FF3399"] #pink!
sns.set_palette(custom_palette)

plt.figure(figsize=(12, 6))  

sns.histplot(df['Hours per day'], bins=20, color='#FF3399', edgecolor='black', alpha=1)
sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color":"black"})

plt.xlabel('Hours per day', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Frequency of how many Hours per Day listened', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.grid(axis='x', linestyle='-', alpha=0.2)
plt.grid(axis='y', linestyle='-', alpha=0.2)

plt.gca().set_facecolor('#333332')
plt.show()

# %% [markdown]
# ### ***Track Two: The Rhythms of Listening Hours per Day***
# ### Here we see how daily music consumption diminishes -- a diminuendo, if you will-- as the hours increase, some preferring over tens of their daily hours filled with music, others with close to none.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
custom_palette = ["#FF9999"]  # Pink color
sns.set_palette(custom_palette)

plt.figure(figsize=(12, 6))

ax = sns.histplot(df['Primary streaming service'], bins=20, color='#FF9999', edgecolor='black', alpha=1)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color": "black"})

plt.xlabel('Primary streaming service', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Frequency of each Streaming Service', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.grid(axis='y', linestyle='-', alpha=0.2)

plt.gca().set_facecolor('#333332')
plt.show()

# %% [markdown]
# ### ***Track Three: Streaming Instrument of Choice***
# ### A histogram that reveals Spotify as the most-played hit in the primary streaming service category, the others not even coming close to it's influence.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
custom_palette = ["#FF3366"] #pink!
sns.set_palette(custom_palette)

plt.figure(figsize=(12, 6))  

sns.histplot(df['Fav genre'], bins=20, color='#FF3366', edgecolor='black', alpha=1)
sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color":"black"})

plt.xlabel('Fav Genre', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Frequency of Preferred Genre', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.grid(axis='x', linestyle='-', alpha=0.2)
plt.grid(axis='y', linestyle='-', alpha=0.2)

plt.gca().set_facecolor('#333332')
plt.show()

# %% [markdown]
# ### ***Track Four: Pick One's Poison***
# ### A graph that displays the symphony of participants' preferred genre, each bar a note of varying pitch and tone in order to create a symphony of diversity in music taste.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='darkgrid')
sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color":"black"})

plt.figure(figsize=(12, 6))  
sns.scatterplot(x=df.index, y=df['BPM'], color='#FF3333', edgecolor='black', alpha=1)

plt.ylim(0, 250)


plt.xlabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('BPM', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Scatter Plot of BPM Values', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})


plt.show()

# %% [markdown]
# ### ***Track Five: Staying on Beat***
# ### A scatterplot that reveals the differing BPM's in listeners' choice of music. We see a wide array of dots, indicating how varying tempos- whether a calming serenade or a high-energy anthem- can influence our survey pool.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('mxmh_survey_results.csv')

genre_columns = ['Frequency [Classical]', 'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
                  'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]', 'Frequency [K pop]',
                  'Frequency [Latin]', 'Frequency [Lofi]', 'Frequency [Metal]', 'Frequency [Pop]',
                  'Frequency [R&B]', 'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]']

melted_df = pd.melt(df, value_vars=genre_columns, var_name='Genre', value_name='Frequency')

sns.set(style='darkgrid')
sns.set_style("darkgrid", {"axes.facecolor": "#FFFFFF", "grid.color":"black"})

plt.figure(figsize=(12, 6))
sns.countplot(data=melted_df, x='Genre', hue='Frequency', palette='rocket')
plt.ylim(0, 600)

plt.xlabel('Genre', fontsize=12 , fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Frequency of Each Genre', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.legend(title='Frequency', loc='upper right', bbox_to_anchor=(1, 1))

plt.xticks(rotation=65, ha='right')

plt.show()

# %% [markdown]
# ### ***Track Six: Wide Taste in Tunes***
# ### This elaborate histogram composes the symphony that is genre consumption - further emphasizing the diversity in music taste throughout the dataset, crescendos distributed all throughout, hitting it's peak in the *never* category for Gospel music.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
custom_palette = ["#FF6699"] 
sns.set_palette(custom_palette)

plt.figure(figsize=(12, 6))

ax = sns.histplot(df['Music effects'], bins=20, color='#FF6699', edgecolor='black', alpha=1)

sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color": "black"})

plt.xlabel('Effect on Mental Health', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Music Effects on Listeners Mental Health', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.grid(axis='y', linestyle='-', alpha=0.2)

plt.gca().set_facecolor('#333332')
plt.show()

# %% [markdown]
# ### ***Track Seven: Musical Mentality***
# ### This histogram paints a picture of music's frequency on self-reported mental health impact: a composition that intertwines music and mental well-being.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('mxmh_survey_results.csv')

categories = ['Anxiety', 'Depression', 'Insomnia', 'OCD']
frequencies = [
    df['Anxiety'].value_counts().sort_index().tolist(),
    df['Depression'].value_counts().sort_index().tolist(),
    df['Insomnia'].value_counts().sort_index().tolist(),
    df['OCD'].value_counts().sort_index().tolist()
]

num_categories = len(categories)
bar_width = 0.2

positions = np.arange(len(set(df['Anxiety'].tolist())))

colors = ['#FF3366', '#FF6666', '#FF9966', '#FFCC66']

plt.figure(figsize=(10, 6))

for i in range(len(frequencies)):
    plt.bar(positions + i * bar_width, frequencies[i][:len(positions)], width=bar_width, label=f'Frequency of {categories[i]}', color = colors[i])

plt.xlabel('Frequency')
plt.ylabel('Count')
plt.title('Frequency of Mental Health Issues')
plt.xticks(positions + bar_width / 2, sorted(set(df['Anxiety'].tolist())))

legend = plt.legend()
for text, color in zip(legend.get_texts(), colors):
    text.set_color('#FFFFFF')

plt.show()

# %% [markdown]
# ### ***Track Eight: Symphonic Dissonance***
# ### The frequency of various mental health disorders is tackled in this elaborate histogram. We see how anxiety, depression, OCD and Insomnia harmonize with the listening habits of these very individuals.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
custom_palette = ["#CC6666"]  
sns.set_palette(custom_palette)

plt.figure(figsize=(12, 6))

ax = sns.histplot(df['Foreign languages'], bins=20, color='#CC6666', edgecolor='black', alpha=1)

sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color": "black"})

plt.xlabel('Foreign Music Listener', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Listeners of Music in Foreign Languages ', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.grid(axis='y', linestyle='-', alpha=0.2)

plt.gca().set_facecolor('#333332')
plt.show()

# %% [markdown]
# ### ***Track Nine: International Listeners***
# ### Each bar of this histogram that represents whether our listeners listen to music in a foreign language, touching on a new dynamic: cultural diversity within the dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
custom_palette = ["#FFCCCC"]  
sns.set_palette(custom_palette)

plt.figure(figsize=(12, 6))

ax = sns.histplot(df['Instrumentalist'], bins=20, color='#FFCCCC', edgecolor='black', alpha=1)

sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color": "black"})

plt.xlabel('Do they play an instrument?', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Frequency of Instrumentalists', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.grid(axis='y', linestyle='-', alpha=0.2)

plt.gca().set_facecolor('#333332')
plt.show()

# %% [markdown]
# ### ***Track Ten: Self-Made Symphonics***
# ### We are shown here the number of participants who engage in playing an instrument of their own-- another instrument, a diverse statistic, to add to the symphony that is our research analysis.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='darkgrid')
custom_palette = ["#CC6699"]  
sns.set_palette(custom_palette)

plt.figure(figsize=(12, 6))

ax = sns.histplot(df['Composer'], bins=20, color='#CC6699', edgecolor='black', alpha=1)
sns.set_style("darkgrid", {"axes.facecolor": "#333332", "grid.color": "black"})

plt.xlabel('Do they compose their own music?', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.ylabel('Frequency', fontsize=12, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})
plt.title('Frequency of Composers', fontsize=14, fontdict={'family': 'serif', 'weight': 'bold', 'style': 'italic'})

plt.grid(axis='y', linestyle='-', alpha=0.2)

plt.gca().set_facecolor('#333332')
plt.show()

# %% [markdown]
# ### ***Track Eleven: The Composer Club***
# ### Through this histogram, it appears our participants are no stranger to the conducting of their own melodies. We add a layer of understanding to a dataset that emphasizes the vastness of musical diversity among respondents.

# %% [markdown]
# ### ------------------------------------------------------------

# %% [markdown]
# # ***Final Graphs / Bonus Tracks***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_path = 'mxmh_survey_results.csv'  
df = pd.read_csv(data_path)

mental_health_columns = ['Anxiety', 'Depression', 'Insomnia', 'OCD']
genre_columns = [col for col in df.columns if 'Frequency [' in col]
df_long = pd.melt(df, id_vars=mental_health_columns, value_vars=genre_columns, var_name='Genre', value_name='Frequency')
df_long['Genre'] = df_long['Genre'].str.extract(r'Frequency \[(.*?)\]')[0] 
frequency_to_ordinal = {
    'Never': 0,
    'Rarely': 1,
    'Sometimes': 2,
    'Frequently': 3,
    'Very frequently': 4
}
df_long['Frequency_Ordinal'] = df_long['Frequency'].map(frequency_to_ordinal)
df_grouped_anxiety = df_long.groupby(['Genre', 'Frequency_Ordinal'])['Anxiety'].mean().reset_index()

df_pivot_anxiety = df_grouped_anxiety.pivot(index="Frequency_Ordinal", columns="Genre", values="Anxiety") 

# heatmap!!!!
plt.figure(figsize=(20, 10))
heatmap_anxiety = sns.heatmap(df_pivot_anxiety, annot=True, cmap="gnuplot2", fmt=".2f")
heatmap_anxiety.set_title('Average Anxiety Score by Genre and Listening Frequency', size=20)
heatmap_anxiety.set_xlabel('Genre', size=15)
heatmap_anxiety.set_ylabel('Frequency (Ordinal)', size=15)
plt.xticks(rotation=45, ha="right", size=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ***Bonus Track #1: Anxiety-Riddled Rhythms***
# ### In this heatmap based on how the frequency of listening to certain genres can impact one's mental health, we see a crescendo in anxiety in those who dabble in listening to the genre Metal, and a decrescendo in those who avoid Pop music, with a story possessing many twists, turns and outcomes based on the other research provided.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_path = 'mxmh_survey_results.csv'  
df = pd.read_csv(data_path)

mental_health_columns = ['Anxiety', 'Depression', 'Insomnia', 'OCD']
genre_columns = [col for col in df.columns if 'Frequency [' in col]
df_long = pd.melt(df, id_vars=mental_health_columns, value_vars=genre_columns, var_name='Genre', value_name='Frequency')
df_long['Genre'] = df_long['Genre'].str.extract(r'Frequency \[(.*?)\]')[0] 
frequency_to_ordinal = {
    'Never': 0,
    'Rarely': 1,
    'Sometimes': 2,
    'Frequently': 3,
    'Very frequently': 4
}
df_long['Frequency_Ordinal'] = df_long['Frequency'].map(frequency_to_ordinal)
df_grouped_anxiety = df_long.groupby(['Genre', 'Frequency_Ordinal'])['Depression'].mean().reset_index()
df_pivot_anxiety = df_grouped_anxiety.pivot(index="Frequency_Ordinal", columns="Genre", values="Depression") 

# heatmap!!!!
plt.figure(figsize=(20, 10))
heatmap_anxiety = sns.heatmap(df_pivot_anxiety, annot=True, cmap="seismic", fmt=".2f")
heatmap_anxiety.set_title('Average Depression Score by Genre and Listening Frequency', size=20)
heatmap_anxiety.set_xlabel('Genre', size=15)
heatmap_anxiety.set_ylabel('Frequency (Ordinal)', size=15)
plt.xticks(rotation=45, ha="right", size=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ***Bonus Track #2: Direct Depression Connections***
# ### In this heatmap, we recognize certain patterns that would not be noticed if left in the vast dataset's original presentation. Listeners of metal music find themselves experiencing depression at higher rates, and those who avoid rock music on all accounts or indulge in gospel music often, find depressive emotions to be a rarity.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_path = 'mxmh_survey_results.csv'  
df = pd.read_csv(data_path)

mental_health_columns = ['Anxiety', 'Depression', 'Insomnia', 'OCD']
genre_columns = [col for col in df.columns if 'Frequency [' in col]
df_long = pd.melt(df, id_vars=mental_health_columns, value_vars=genre_columns, var_name='Genre', value_name='Frequency')
df_long['Genre'] = df_long['Genre'].str.extract(r'Frequency \[(.*?)\]')[0] 
frequency_to_ordinal = {
    'Never': 0,
    'Rarely': 1,
    'Sometimes': 2,
    'Frequently': 3,
    'Very frequently': 4
}
df_long['Frequency_Ordinal'] = df_long['Frequency'].map(frequency_to_ordinal)
df_grouped_anxiety = df_long.groupby(['Genre', 'Frequency_Ordinal'])['OCD'].mean().reset_index()
df_pivot_anxiety = df_grouped_anxiety.pivot(index="Frequency_Ordinal", columns="Genre", values="OCD") 

# heatmap!!!!
plt.figure(figsize=(20, 10))
heatmap_anxiety = sns.heatmap(df_pivot_anxiety, annot=True, cmap="plasma", fmt=".2f")
heatmap_anxiety.set_title('Average OCD Score by Genre and Listening Frequency', size=20)
heatmap_anxiety.set_xlabel('Genre', size=15)
heatmap_anxiety.set_ylabel('Frequency (Ordinal)', size=15)
plt.xticks(rotation=45, ha="right", size=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ***Bonus Track #3: OCD Orchestrative Behaviors***
# ### As shown here, we see Obsessive-Compulsive Disorder-based behavior peak in those who listen to primarily R&B music, and plummet in those who only listen to it sometimes-- an interesting conclusion that speaks volumes about R&B music-- but doesn't clarify it's effect nonetheless.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_path = 'mxmh_survey_results.csv'  
df = pd.read_csv(data_path)

mental_health_columns = ['Anxiety', 'Depression', 'Insomnia', 'OCD']
genre_columns = [col for col in df.columns if 'Frequency [' in col]
df_long = pd.melt(df, id_vars=mental_health_columns, value_vars=genre_columns, var_name='Genre', value_name='Frequency')
df_long['Genre'] = df_long['Genre'].str.extract(r'Frequency \[(.*?)\]')[0] 
frequency_to_ordinal = {
    'Never': 0,
    'Rarely': 1,
    'Sometimes': 2,
    'Frequently': 3,
    'Very frequently': 4
}
df_long['Frequency_Ordinal'] = df_long['Frequency'].map(frequency_to_ordinal)
df_grouped_anxiety = df_long.groupby(['Genre', 'Frequency_Ordinal'])['Insomnia'].mean().reset_index()
df_pivot_anxiety = df_grouped_anxiety.pivot(index="Frequency_Ordinal", columns="Genre", values="Insomnia") 

# heatmap!!!!
plt.figure(figsize=(20, 10))
heatmap_anxiety = sns.heatmap(df_pivot_anxiety, annot=True, cmap="jet", fmt=".2f")
heatmap_anxiety.set_title('Average Insomnia Score by Genre and Listening Frequency', size=20)
heatmap_anxiety.set_xlabel('Genre', size=15)
heatmap_anxiety.set_ylabel('Frequency (Ordinal)', size=15)
plt.xticks(rotation=45, ha="right", size=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ***Bonus Track #4: Insomnia Instrumentals***
# ### This final heatmap displays a pattern in those who favor Jazz to also display signs of Insomnia, not like those who listen to country music, who seem to not experience any sleep deprivation of the sort, an interesting conclusion considering the dissonance found in both music genres.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data_path = 'mxmh_survey_results.csv'
df = pd.read_csv(data_path)

df_long = pd.melt(df, id_vars=["Music effects"], value_vars=[col for col in df.columns if col.startswith("Frequency")], 
                  var_name='Genre', value_name='Frequency')

music_effects_mapping = {'No effect': 0, 'Improve': .5, 'Worsen': 1}
df_long['Music effects'] = df_long['Music effects'].map(music_effects_mapping)

plt.figure(figsize=(12, 8))
sns.barplot(data=df_long, x='Music effects', y='Frequency', hue='Genre', ci=None)

plt.title('Averaged Out Reported Music effects by Genre Listening Frequency')
plt.xlabel('Music Effects')
plt.xlim(0,1)
plt.xticks([0, 0.5, 1], ['Improve', 'No effect', 'Worsen'])
plt.ylabel('Frequency')

plt.legend(fontsize='5')

plt.show()
# Out:
# /var/folders/j6/_5nzrlts32l_krf01lvmcwk40000gn/T/ipykernel_98364/1461459652.py:15: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df_long, x='Music effects', y='Frequency', hue='Genre', ci=None)

# %% [markdown]
# ### ***Bonus Track #5: Self-Reported Musical Impact***
# ### When all genres are taken into consideration and averaged out, it appears that the composition reveal that the general average regardless of genre and frequency of it being listened to, all falls between *No Effect* and *Improve*, with those who frequently listen to gospel music being the only group to record that music's general effect is between worsening their mental well-being and not having an effect on it.

# %% [markdown]
# ### -----------------------------------------------------------------------

# %% [markdown]
# ## ***Finale/Final Track***
# ### In conclusion, my symphony hoped to properly tell the story that is the effects of music on mental health. Starting with some simple histograms, we managed to get a basic sense of our respondents and their notable qualities and traits. We followed those up with more elaborate histograms and scatterplots that touched more on the diversity and vastness present in our dataset in regards to mental health diagnoses, genre frequencies and BPM records. We then returned to a consistent, simple melody of histograms that told different stories which highlighted how sporadic the data recorded was, as it took into account variables I had never thought of to include, such as foreign music listening or whether a respondent composes their own music. Survey questions like these may have made for simple graphs, but they certainly did not make for a monotonous, dull story being told. Finally, we hit a crescendo with varying heat maps and stacked bar graphs that directly connected to the question being asked -- whether or not music individuals' music streaming habits, including genres and listening patterns, correlate with their reported mental health factors such as anxiety, depression, insomnia, and OCD? We saw patterns in those who indulged in all sorts of music, ranging from gospel to metal. There were of course disconnects, diminuendos, where we saw issues arise, such as heatmaps not developing properly, implying a disconnect between the parameters necessary for the graph and the data, or grids remaining blank despite the proper ranges and having to make some categorical variables numerical for the sake of a more digestible graph. In the future, I hope to analyze the raw data a bit more extensively in order to pinpoint which visualizations would be the most ideal rather than just enough. Overall, as this final track commences, I hope you can see the harmonious story told by the visualization conducted regarding music and it's effects on mental health.

# %% [markdown]
# # Citations
#
# ### Rasgaitis, C. (2022, November 21). Music & Mental Health Survey Results. Kaggle. https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results/data
